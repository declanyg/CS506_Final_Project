# %%
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## Get market data for past year

# %%
START = "2023-09-01"
END = "2024-09-01"
ticker = "QQQ"

# spy = yf.Ticker("SPY")

stock_df = yf.download(ticker, start=START, end=END)
stock_df = stock_df.xs(ticker, level='Ticker', axis=1)


stock_df['time_published'] = stock_df.index
stock_df['time_published'] = pd.to_datetime(stock_df['time_published'])
stock_df['time_published'] = stock_df['time_published'].dt.date
display(stock_df)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Adj Close       Close        High         Low  \
# Date
# 2023-09-01 00:00:00+00:00  374.475861  377.589996  380.829987  376.079987
# 2023-09-05 00:00:00+00:00  374.951904  378.070007  379.309998  375.829987
# 2023-09-06 00:00:00+00:00  371.649384  374.739990  377.630005  372.700012
# 2023-09-07 00:00:00+00:00  368.991486  372.059998  372.850006  369.149994
# 2023-09-08 00:00:00+00:00  369.507202  372.579987  374.850006  371.600006
# ...                               ...         ...         ...         ...
# 2024-08-26 00:00:00+00:00  474.672974  475.339996  480.380005  473.239990
# 2024-08-27 00:00:00+00:00  476.090973  476.760010  477.839996  471.709991
# 2024-08-28 00:00:00+00:00  470.688568  471.350006  477.019989  467.890015
# 2024-08-29 00:00:00+00:00  469.999542  470.660004  477.929993  469.369995
# 2024-08-30 00:00:00+00:00  475.601654  476.269989  476.899994  470.510010
#
# Price                            Open    Volume time_published
# Date
# 2023-09-01 00:00:00+00:00  380.399994  39772400     2023-09-01
# 2023-09-05 00:00:00+00:00  376.769989  32344200     2023-09-05
# 2023-09-06 00:00:00+00:00  377.279999  42998700     2023-09-06
# 2023-09-07 00:00:00+00:00  370.209991  52060700     2023-09-07
# 2023-09-08 00:00:00+00:00  372.010010  35800100     2023-09-08
# ...                               ...       ...            ...
# 2024-08-26 00:00:00+00:00  479.450012  27452600     2024-08-26
# 2024-08-27 00:00:00+00:00  473.690002  27510000     2024-08-27
# 2024-08-28 00:00:00+00:00  476.290009  37372400     2024-08-28
# 2024-08-29 00:00:00+00:00  473.279999  41081500     2024-08-29
# 2024-08-30 00:00:00+00:00  475.040009  33466500     2024-08-30
#
# [251 rows x 7 columns]

# %%
print(stock_df.index)
# fig = plt.figure(figsize=(10,6))
# plt.title(f"{ticker} close price against date from 2022-09-01 to 2024-09-01")
# plt.plot(df.index, df['Adj Close'], label="Adj Close", color="blue")
# quarter_starts = pd.to_datetime(["2022-09-01", "2022-12-31", "2023-03-31", "2023-06-30",
#                                   "2023-09-30", "2023-12-31", "2024-03-31", "2024-06-30", "2024-09-30"])

# for date in quarter_starts:
#     plt.axvline(x=date, color='red', linestyle='--', linewidth=0.8)


# plt.savefig('QQQ_price.png')
# Out:
# DatetimeIndex(['2023-09-01 00:00:00+00:00', '2023-09-05 00:00:00+00:00',
#                '2023-09-06 00:00:00+00:00', '2023-09-07 00:00:00+00:00',
#                '2023-09-08 00:00:00+00:00', '2023-09-11 00:00:00+00:00',
#                '2023-09-12 00:00:00+00:00', '2023-09-13 00:00:00+00:00',
#                '2023-09-14 00:00:00+00:00', '2023-09-15 00:00:00+00:00',
#                ...
#                '2024-08-19 00:00:00+00:00', '2024-08-20 00:00:00+00:00',
#                '2024-08-21 00:00:00+00:00', '2024-08-22 00:00:00+00:00',
#                '2024-08-23 00:00:00+00:00', '2024-08-26 00:00:00+00:00',
#                '2024-08-27 00:00:00+00:00', '2024-08-28 00:00:00+00:00',
#                '2024-08-29 00:00:00+00:00', '2024-08-30 00:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', name='Date', length=251, freq=None)

# %%
news_df = pd.read_csv('technology_news_data (6 day increments).csv')
news_df['time_published'] = pd.to_datetime(news_df['time_published'])
news_df['time_published'] = news_df['time_published'].dt.date
display(news_df)
# Out:
#                                                    title  \
# 0      RPT Realty  ( NYSE:RPT )  Now Covered by Analy...
# 1      Urstadt Biddle Properties  ( NYSE:UBA )  Now C...
# 2      Ryerson  ( NYSE:RYI )  Downgraded by StockNews...
# 3      Vista Outdoor  ( NYSE:VSTO )  Upgraded to "Buy...
# 4      Invesco  ( NYSE:IVZ )  Downgraded by StockNews...
# ...                                                  ...
# 19064  Harris campaign launches $370 million fall ad ...
# 19065  SRG FINAL DEADLINE: ROSEN, SKILLED INVESTOR CO...
# 19066  Meet the Newest Artificial Intelligence  ( AI ...
# 19067  3 Growth Stocks Wall Street Might Be Sleeping ...
# 19068  1 Stock I Wouldn't Touch With a 10-Foot Pole, ...
#
#                                                      url time_published  \
# 0      https://www.defenseworld.net/2023/09/15/rpt-re...     2023-09-15
# 1      https://www.defenseworld.net/2023/09/15/urstad...     2023-09-15
# 2      https://www.defenseworld.net/2023/09/15/ryerso...     2023-09-15
# 3      https://www.defenseworld.net/2023/09/15/vista-...     2023-09-15
# 4      https://www.defenseworld.net/2023/09/15/invesc...     2023-09-15
# ...                                                  ...            ...
# 19064  https://www.cnbc.com/2024/08/17/harris-walz-ad...     2024-08-17
# 19065  https://www.benzinga.com/pressreleases/24/08/g...     2024-08-17
# 19066  https://www.fool.com/investing/2024/08/17/meet...     2024-08-17
# 19067  https://www.fool.com/investing/2024/08/17/3-gr...     2024-08-17
# 19068  https://www.fool.com/investing/2024/08/17/1-st...     2024-08-17
#
#               source  overall_sentiment_score overall_sentiment_label  \
# 0      Stocknews.com                 0.319663        Somewhat-Bullish
# 1      Stocknews.com                 0.313022        Somewhat-Bullish
# 2      Stocknews.com                 0.283105        Somewhat-Bullish
# 3      Stocknews.com                 0.309736        Somewhat-Bullish
# 4      Stocknews.com                 0.324543        Somewhat-Bullish
# ...              ...                      ...                     ...
# 19064           CNBC                 0.141113                 Neutral
# 19065       Benzinga                 0.169754        Somewhat-Bullish
# 19066    Motley Fool                 0.170337        Somewhat-Bullish
# 19067    Motley Fool                 0.361954                 Bullish
# 19068    Motley Fool                 0.043283                 Neutral
#
#                                         ticker_sentiment
# 0      [{'ticker': 'BK', 'relevance_score': '0.143415...
# 1      [{'ticker': 'SSTK', 'relevance_score': '0.0958...
# 2      [{'ticker': 'BK', 'relevance_score': '0.12546'...
# 3      [{'ticker': 'BLK', 'relevance_score': '0.13496...
# 4      [{'ticker': 'SSTK', 'relevance_score': '0.0506...
# ...                                                  ...
# 19064  [{'ticker': 'GOOG', 'relevance_score': '0.1364...
# 19065  [{'ticker': 'META', 'relevance_score': '0.0644...
# 19066  [{'ticker': 'SERV', 'relevance_score': '0.3926...
# 19067  [{'ticker': 'NKE', 'relevance_score': '0.28223...
# 19068  [{'ticker': 'MSFT', 'relevance_score': '0.0740...
#
# [19069 rows x 7 columns]

# %%
df1 = stock_df[['time_published', 'Adj Close']]
df2 = news_df[['time_published', 'source', 'overall_sentiment_score']]
average_sentiment_df = df2.groupby(['time_published', 'source'], as_index=False)['overall_sentiment_score'].mean()
average_sentiment_df.rename(columns={'overall_sentiment_score': 'average sentiment score'}, inplace=True)
pivot_df = average_sentiment_df.pivot(index='time_published', columns='source', values='average sentiment score')
pivot_df.reset_index(inplace=True)
pivot_df.fillna(0, inplace=True)
combined_df = pd.merge(df1, pivot_df, on='time_published', how='inner')
# # combined_df['time_published'] = pd.to_datetime(combined_df['time_published'])
# # combined_df['time_published'] = (combined_df['time_published'] - pd.to_datetime('1970-01-01')).dt.days
# df_encoded = pd.get_dummies(combined_df, columns=['source'])
# display(df_encoded)
display(combined_df)
# Out:
#    time_published   Adj Close  Al Jareeza  Associated Press   Barrons  \
# 0      2023-09-15  367.751770   -0.042483         -0.125449  0.055516
# 1      2023-09-29  355.829529   -0.094662         -0.049722  0.098913
# 2      2023-10-12  367.410126    0.000000          0.000000  0.000000
# 3      2023-10-13  362.791809   -0.132722         -0.110395 -0.006599
# 4      2023-10-27  342.957794   -0.115070          0.024476  0.036064
# 5      2023-11-10  375.812500    0.175569         -0.121300  0.059941
# 6      2023-11-24  386.856750   -0.184925         -0.093546 -0.115557
# 7      2023-12-08  389.498627    0.181953         -0.037172  0.140394
# 8      2023-12-21  405.801270    0.000000         -0.120424  0.000000
# 9      2023-12-22  406.408356   -0.057851          0.000567  0.413111
# 10     2023-12-28  409.529510    0.000000         -0.086765  0.000000
# 11     2023-12-29  407.757172   -0.132928         -0.070839 -0.052033
# 12     2024-01-05  395.042145    0.000000         -0.009964  0.073161
# 13     2024-01-18  411.212280    0.000000         -0.031495  0.000000
# 14     2024-01-19  419.366974    0.000000         -0.038831  0.207431
# 15     2024-02-02  427.163330    0.118143          0.064877  0.088787
# 16     2024-02-15  432.639618    0.000000         -0.135974  0.000000
# 17     2024-02-16  428.716583   -0.123655         -0.038342  0.066053
# 18     2024-03-01  443.691833   -0.101564         -0.070116  0.146681
# 19     2024-03-15  432.052185   -0.230668          0.044275  0.121492
# 20     2024-03-28  442.683319   -0.067979         -0.080509  0.000000
# 21     2024-04-11  444.039246    0.000000         -0.216174  0.000000
# 22     2024-04-12  436.960449   -0.044797         -0.074710  0.192306
# 23     2024-04-26  429.712189    0.000000         -0.018636  0.079628
# 24     2024-05-10  440.739136   -0.091241          0.036411  0.154945
# 25     2024-05-23  452.304504    0.000000         -0.044956  0.000000
# 17               0.255205    0.000000      -0.084464      0.084626
# 18               0.230192    0.000000       0.012287      0.109409
# 19               0.030992    0.000000       0.037299      0.236029
# 20               0.000000    0.000000       0.036682      0.141024
# 21               0.000000    0.000000       0.000000      0.000000
# 22               0.246557    0.000000       0.196511      0.000000
# 23               0.185769    0.000000       0.029579      0.073588
# 24               0.276652    0.000000       0.020592      0.000000
# 25               0.000000    0.000000       0.000000      0.000000
# 26               0.298786    0.000000       0.105845      0.000000
# 27               0.149297    0.000000       0.076551      0.000000
# 28              -0.140976    0.000000       0.000000      0.000000
# 29               0.299302    0.000000       0.167977      0.000000
# 30               0.279170    0.000000       0.000000      0.000000
# 31               0.144212    0.000000      -0.067347      0.000000
# 32               0.000000    0.000000       0.000000      0.000000
# 33               0.000000    0.000000       0.000000      0.000000
# 34               0.000000    0.000000       0.000000      0.000000
# 35               0.000000    0.000000       0.000000      0.000000
# 36               0.000000    0.000000       0.000000      0.000000
#
#     Wall Street Journal  Zacks Commentary
# 0              0.000000          0.276678
# 1              0.000000          0.246524
# 2              0.000000          0.370484
# 3              0.000000          0.235242
# 4              0.000000          0.185696
# 5              0.000000          0.231723
# 6              0.475207          0.235046
# 7              0.138606          0.239282
# 8              0.000000          0.231955
# 9              0.245020          0.255826
# 10             0.000000          0.207731
# 11             0.000000          0.268049
# 12             0.290045          0.241447
# 13             0.000000          0.000000
# 14             0.000000          0.234360
# 15             0.000000          0.236312
# 16             0.000000          0.266938
# 17             0.000000          0.192677
# 18             0.000000          0.246513
# 19             0.000000          0.255334
# 20             0.000000          0.259305
# 21             0.000000          0.200163
# 22             0.000000          0.252324
# 23             0.000000          0.200211
# 24             0.000000          0.218832
# 25             0.000000          0.155453
# 26             0.000000          0.257843
# 27             0.000000          0.232871
# 28             0.000000          0.183210
# 29             0.000000          0.241708
# 30             0.000000          0.226261
# 31             0.000000          0.277359
# 32             0.000000          0.154603
# 33             0.000000          0.247803
# 34             0.000000          0.182921
# 35             0.000000          0.125880
# 36             0.000000          0.270649
#
# [37 rows x 42 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X = combined_df.drop(['Adj Close', 'time_published'], axis=1)
y = combined_df["Adj Close"]

X_train, X_test, y_train, y_test, time_train, time_test = train_test_split(
    X, y, combined_df['time_published'], test_size=0.2, random_state=506
)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# Evaluate the model (using metrics like Mean Squared Error, R-squared, etc.)
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 6784.357420474878
# R-squared: -4.503029268691318

# %%
predictions_df = combined_df.copy()
predictions_df['predicted_price'] = model.predict(X)
fitted_values = model.predict(X)

plt.figure(figsize=(12, 6))

# Plot actual prices
plt.scatter(predictions_df['time_published'], y, color='blue', label='Actual Prices')

# Plot predicted prices
plt.scatter(predictions_df['time_published'], predictions_df['predicted_price'], color='red', label="Predicted Prices")

# Plot the linear regression fit line
plt.plot(predictions_df['time_published'], fitted_values, color='green', label='Linear Regression Fit', linestyle='-', linewidth=2)

# Formatting the plot
plt.title('Actual Prices vs Predicted Prices Over Time with Linear Regression Fit')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()  # Adjust layout to fit all elements
plt.show()
