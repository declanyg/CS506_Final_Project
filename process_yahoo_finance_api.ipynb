# %%
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Get market data for past year

# %%
START = "2022-09-01"
END = "2024-09-01"
ticker = "QQQ"

# spy = yf.Ticker("SPY")

df = yf.download(ticker, start=START, end=END)
df = df.xs(ticker, level='Ticker', axis=1)

print(df.head())
print(df.columns)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Adj Close       Close        High         Low  \
# Date
# 2022-09-01 00:00:00+00:00  294.828644  299.399994  299.779999  292.950012
# 2022-09-02 00:00:00+00:00  290.663300  295.170013  303.750000  293.519989
# 2022-09-06 00:00:00+00:00  288.575592  293.049988  296.600006  290.869995
# 2022-09-07 00:00:00+00:00  294.405212  298.970001  299.989990  293.269989
# 2022-09-08 00:00:00+00:00  295.931580  300.519989  301.869995  295.450012
#
# Price                            Open    Volume
# Date
# 2022-09-01 00:00:00+00:00  296.720001  57990700
# 2022-09-02 00:00:00+00:00  302.339996  64666800
# 2022-09-06 00:00:00+00:00  295.660004  57005400
# 2022-09-07 00:00:00+00:00  293.540009  49260400
# 2022-09-08 00:00:00+00:00  296.850006  55649800
# Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object', name='Price')

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(df.index, df['Adj Close'], label="Adj Close", color="blue")
quarter_starts = pd.to_datetime(["2022-09-01", "2022-12-31", "2023-03-31", "2023-06-30", 
                                  "2023-09-30", "2023-12-31", "2024-03-31", "2024-06-30", "2024-09-30"])

for date in quarter_starts:
    plt.axvline(x=date, color='red', linestyle='--', linewidth=0.8)


plt.title(f"{ticker} close price against date from 2022-09-01 to 2024-09-01")
# Out:
# Text(0.5, 1.0, 'QQQ close price against date from 2022-09-01 to 2024-09-01')

# %%
plt.savefig('./plots/QQQ_price.png')
